# %%
from preprocess import get_data
import os

# %%
data_dir = '/Users/nakagawaayato/compe/signate_hiroshima/original_data/train'

# %% [markdown]
# ## 変数を返す

# %%
rain, rain_st, tide, tide_st, water, water_st, dam, river_table, river_system_table = get_data(data_dir)
# Out:
# 1. データ読み込み
#  => complete
# 2. 3つのデータに前処理 & database化
#  => complete
# 3. 1つのstationに対し値を一列に時系列で並べる
#  => complete
# 4. 河川名、水系名について処理
#  => complete
# 5. 変数を返す
#
# All Complete!!!

# %%
water_st[['id', 'station']].set_index('station')['id'].to_dict()
# Out:
# {'七宝': 0,
#  '七社': 1,
#  '万能倉': 2,
#  '三入南': 3,
#  '三次(国)': 4,
#  '三津': 5,
#  '三玉': 6,
#  '三篠橋(国)': 7,
#  '上中': 8,
#  '上原橋(国)': 9,
#  '上壱': 10,
#  '上安': 11,
#  '上安井': 12,
#  '上安田(国)': 13,
#  '上庄(国)': 14,
#  '上戸手(国)': 15,
#  '上甲立': 16,
#  '上高暮': 17,
#  '下ヶ原(国)': 18,
#  '下原': 19,
#  '下土師(国)': 20,
#  '下小原': 21,
#  '下布野': 22,
#  '下志和地': 23,
#  '下見': 24,
#  '下野': 25,
#  '中之町': 26,
#  '中地': 27,
#  '中島': 28,
#  '中河内': 29,
#  '中深川(国)': 30,
#  '中野': 31,
#  '中野(国)': 32,
#  '丸門田': 33,
#  '久地': 34,
#  '亀山': 35,
#  '二森': 36,
#  '二河': 37,
#  '今津': 38,
#  '今田': 39,
#  '伊尾': 40,
#  '伊尾(国)': 41,
#  '出雲': 42,
#  '前原': 43,
#  '加茂': 44,
#  '加計(国)': 45,
#  '十日市': 46,
#  '南原': 47,
#  '南方': 48,
#  '南畑敷(国)': 49,
#  '友和': 50,
#  '古川(国)': 51,
#  '古市': 52,
#  '古河': 53,
#  '吉田(国)': 54,
#  '向原': 55,
#  '向田': 56,
#  '呉地': 57,
#  '和木': 58,
#  '和知': 59,
#  '土居(国)': 60,
#  '多治比': 61,
#  '大朝': 62,
#  '大橋': 63,
#  '大津(国)': 64,
#  '大須': 65,
#  '大黒': 66,
#  '失平': 67,
#  '奥条': 68,
#  '宇津戸川(国)': 69,
#  '宮内': 70,
# ...

# %% [markdown]
# ## directoryに保存

# %% [markdown]
# save_dirを指定するとそのフォルダに出来上がった9つのcsvファイルを保存します。

# %%
save_dir = '/Users/nakagawaayato/compe/signate_hiroshima/data/temp'

# %%
get_data(data_dir, save_dir)
# Out:
# 1. データ読み込み
#  => complete
# 2. 3つのデータに前処理 & database化
#  => complete
# 3. 1つのstationに対し値を一列に時系列で並べる
#  => complete
# 4. 河川名、水系名について処理
#  => complete
# 5. 保存
#
# All Complete!!!
