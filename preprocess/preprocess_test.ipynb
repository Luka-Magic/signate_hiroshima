# %%
from pre0001.preprocess import get_data
import os

# %%
data_dir = '/Users/nakagawaayato/compe/signate_hiroshima/original_data/train'

# %% [markdown]
# ## 変数を返す

# %%
rain, rain_st, tide, tide_st, water, water_st, dam, river_table, river_system_table = get_data(data_dir)
# Out:
# 1. データ読み込み
#  => complete
# 2. 3つのデータに前処理 & database化
#  => complete
# 3. 1つのstationに対し値を一列に時系列で並べる
#  => complete
# 4. 河川名、水系名について処理
#  => complete
# 5. 変数を返す
#
# All Complete!!!

# %% [markdown]
# ## directoryに保存

# %% [markdown]
# save_dirを指定するとそのフォルダに出来上がった9つのcsvファイルを保存します。

# %%
save_dir = '/Users/nakagawaayato/compe/signate_hiroshima/data/pre0001'

# %%
get_data(data_dir, save_dir)
# Out:
# 1. データ読み込み
#  => complete
# 2. 3つのデータに前処理 & database化
# /Users/nakagawaayato/compe/signate_hiroshima/signate_hiroshima/preprocess/pre0001/utils/rain.py:57: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   bool_ = rain_st['観測所名称'].str.contains(st)
# /Users/nakagawaayato/compe/signate_hiroshima/signate_hiroshima/preprocess/pre0001/utils/rain.py:67: FutureWarning: The default value of regex will change from True to False in a future version.
#   rain_st.loc[:, '観測所名称'] = rain_st['観測所名称'].str.replace(r'\(砂防\)', '')
# /Users/nakagawaayato/compe/signate_hiroshima/signate_hiroshima/preprocess/pre0001/utils/water.py:12: FutureWarning: The default value of regex will change from True to False in a future version.
#   water['station'] = water['station'].str.replace(r'\(電\)', '')
# /Users/nakagawaayato/compe/signate_hiroshima/signate_hiroshima/preprocess/pre0001/utils/water.py:16: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   bool_ = water_st['観測所名称'].str.contains(st)
# /Users/nakagawaayato/compe/signate_hiroshima/signate_hiroshima/preprocess/pre0001/utils/water.py:27: FutureWarning: The default value of regex will change from True to False in a future version.
#   water_st.loc[:, '河川名'] = water_st['河川名'].str.replace('\\n', '')
#  => complete
# 3. 1つのstationに対し値を一列に時系列で並べる
#  => complete
# 4. 河川名、水系名について処理
#  => complete
# 5. 保存
#
# All Complete!!!
